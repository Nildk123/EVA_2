# %% [markdown]
# <a href="https://colab.research.google.com/github/Nildk123/EVA_2/blob/main/S12/EVA_S12_Assignment_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
root_dir = "/content/drive/My Drive/Week12/"
os.chdir(root_dir)

# %%
from Annotator import Annotator

# %%
annotate = Annotator('annotated.json', 'results.csv')

# %%
annotate.show_bboxes()

# %%
annotate.create_cluster(10)

# %%
annotate.show_k(5)
# Out:
# Centroids: [[0.11514284 0.10816361]
#  [0.31367721 0.53710852]
#  [0.17726664 0.26362189]
#  [0.33844265 0.24463796]
#  [0.6161653  0.41982156]]
# Mean IOU: 0.6345520015371641

# %%
annotate.show_k(4)
# Out:
# Centroids: [[0.60952026 0.40247788]
#  [0.11631031 0.11856223]
#  [0.31482964 0.54017966]
#  [0.24022222 0.2650318 ]]
# Mean IOU: 0.6034404721161396

# %%
annotate.show_k(6)
# Out:
# Centroids: [[0.21853892 0.13228396]
#  [0.6161653  0.41982156]
#  [0.31140099 0.5398398 ]
#  [0.17046591 0.27329522]
#  [0.35087726 0.26866211]
#  [0.09013909 0.1072028 ]]
# Mean IOU: 0.6590775104772216
